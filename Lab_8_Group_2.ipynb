# %%
import numpy as np 
import matplotlib.pyplot as plt
import scipy
from scipy.io.wavfile import read

# %%
import numpy as np 
from scipy.io.wavfile import read

sample_rate, data = read('combine pitch.wav')

if len(data.shape) > 1:
    data = data.mean(axis=1)
time = np.arange(len(data)) / sample_rate

data_ftf = np.fft.fft(data)
frequencies = np.fft.fftfreq(len(data), d=1/sample_rate)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(time, data, color='teal', linewidth=1)
plt.title("Time Domain Signal")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")

plt.subplot(1, 2, 2)
plt.plot(time, data, color='blue', linewidth=1)
plt.title("Frequency Domain Signal")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\202014480\AppData\Local\Temp\ipykernel_2992\666540959.py:4: WavFileWarning: Reached EOF prematurely; finished at 1265743 bytes, expected 4294967303 bytes from header.
#   sample_rate, data = read('combine pitch.wav')

# %%
import numpy as np 
from scipy.io.wavfile import read

sample_rate, data = read('Low pitch.wav')

if len(data.shape) > 1:
    data = data.mean(axis=1)
time = np.arange(len(data)) / sample_rate

data_ftf = np.fft.fft(data)
frequencies = np.fft.fftfreq(len(data), d=1/sample_rate)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(time, data, color='teal', linewidth=1)
plt.title("Time Domain Signal")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")

plt.subplot(1, 2, 2)
plt.plot(time, data, color='blue', linewidth=1)
plt.title("Frequency Domain Signal")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\202014480\AppData\Local\Temp\ipykernel_2992\2909395141.py:4: WavFileWarning: Reached EOF prematurely; finished at 532559 bytes, expected 4294967303 bytes from header.
#   sample_rate, data = read('Low pitch.wav')

# %%
import numpy as np 
from scipy.io.wavfile import read

sample_rate, data = read('Mid pitch.wav')

if len(data.shape) > 1:
    data = data.mean(axis=1)
time = np.arange(len(data)) / sample_rate

data_ftf = np.fft.fft(data)
frequencies = np.fft.fftfreq(len(data), d=1/sample_rate)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(time, data, color='teal', linewidth=1)
plt.title("Time Domain Signal")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")

plt.subplot(1, 2, 2)
plt.plot(time, data, color='blue', linewidth=1)
plt.title("Frequency Domain Signal")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\202014480\AppData\Local\Temp\ipykernel_2992\417232108.py:4: WavFileWarning: Reached EOF prematurely; finished at 440399 bytes, expected 4294967303 bytes from header.
#   sample_rate, data = read('Mid pitch.wav')

# %%
import numpy as np 
from scipy.io.wavfile import read

sample_rate, data = read('High pitch.wav')

if len(data.shape) > 1:
    data = data.mean(axis=1)
time = np.arange(len(data)) / sample_rate

data_ftf = np.fft.fft(data)
frequencies = np.fft.fftfreq(len(data), d=1/sample_rate)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(time, data, color='teal', linewidth=1)
plt.title("Time Domain Signal")
plt.xlabel("Time (s)")
plt.ylabel("Amplitude")

plt.subplot(1, 2, 2)
plt.plot(time, data, color='blue', linewidth=1)
plt.title("Frequency Domain Signal")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Magnitude")

plt.tight_layout()
plt.show()
# Out:
# C:\Users\202014480\AppData\Local\Temp\ipykernel_2992\54714521.py:4: WavFileWarning: Reached EOF prematurely; finished at 450639 bytes, expected 4294967303 bytes from header.
#   sample_rate, data = read('High pitch.wav')
